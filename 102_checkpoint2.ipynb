# %% [markdown]
# <a href="https://colab.research.google.com/github/shreybhate09/website/blob/master/102_checkpoint2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
from sklearn.linear_model import LogisticRegression as LR
from scipy import stats 
import pickle
from datascience import *
#import pymc3 as pm 
#from pymc3 import * 
# %matplotlib inline
import seaborn as sns

# %%
dem_raw = "https://raw.githubusercontent.com/prasannguruprasad/d102-final-project/main/dem_candidates.csv"

# %%
df = pd.read_csv(dem_raw,index_col=0,parse_dates=[0])

# %%
df.iloc[:,10:20]
# Out:
#                         Won Primary      Race Veteran? LGBTQ?  \
# Candidate
# Anthony White (Alabama)          No  Nonwhite      Yes     No
# Christopher Countryman           No     White       No    Yes
# Doug "New Blue" Smith            No     White      Yes     No
# James C. Fields                  No  Nonwhite      Yes     No
# Sue Bell Cobb                    No     White       No     No
# ...                             ...       ...      ...    ...
# Talley Sergent                  Yes     White       No     No
# Janice Hagerman                  No     White       No     No
# Paul Davis                       No     White       No     No
# Richard Ojeda                   Yes  Nonwhite      Yes     No
# Shirley Love                     No     White       No     No
#
#                         Elected Official? Self-Funder? STEM? Obama Alum?  \
# Candidate
# Anthony White (Alabama)                No           No    No          No
# ...

# %%
race = df.iloc[:,11].sample(811).values
shuffled = pd.DataFrame(df.index, race)
shuffled.head()
# Out:
#                              0
# Candidate
# Anthony White (Alabama)  White
# Christopher Countryman     NaN
# Doug "New Blue" Smith    White
# James C. Fields          White
# Sue Bell Cobb            White

# %%
def ab_test(id):
  shuffled = df.iloc[:,id].sample(len(df)).values
  

for i in range(1000):
# Out:
# <ipython-input-78-a707df892455>:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   shuffled = pd.DataFrame(reconfig).groupby("identifier").mean().values
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-a707df892455> in <cell line: 8>()
#       7 ts = []
#       8 for i in range(1000):
# ----> 9   ts.append(ab_test("Race"))
#      10 ts
#
# <ipython-input-78-a707df892455> in ab_test(id)
#       3   reconfig = {"candidate":df.index,"primary%":df['Primary %'],"identifier": shuffled_vals}
#       4   shuffled = pd.DataFrame(reconfig).groupby("identifier").mean().values
# ----> 5   return float(np.diff(shuffled))
#       6
#       7 ts = []
#
# ...

# %%
pd.DataFrame(df.key)

# %%
df.index
# Out:
# Index(['Anthony White (Alabama)', 'Christopher Countryman',
#        'Doug "New Blue" Smith', 'James C. Fields', 'Sue Bell Cobb',
#        'Walt Maddox', 'Lizzetta Hill McConnell', 'Robert Kennedy Jr.',
#        'Audri Scott Williams', 'Tabitha Isner',
#        ...
#        'Thomas Cramer', 'Kendra Fershee', 'Ralph Baxter', 'Tom Payne',
#        'Aaron Scheinberg', 'Talley Sergent', 'Janice Hagerman', 'Paul Davis',
#        'Richard Ojeda', 'Shirley Love'],
#       dtype='object', name='Candidate', length=811)
